# %%
dbutils.widgets.text('Environment', 'dev', 'Set current environment/catalog name')
env = dbutils.widgets.get('Environment')

# %%
# %run ./02-setup

# %%
SH = SetupHelper(env)
SH.cleanup()

# %%
dbutils.notebook.run('./07-run', 600, {'Environment': env, 'RunType': 'once'})

# %%
# %run ./03-history-loader

# %%
HL = HistoryLoader(env)
SH.validate()
HL.validate()

# %%
# %run ./10-producer

# %%
PR = Producer()
PR.produce(1)
PR.validate(1)
dbutils.notebook.run("./07-run", 600, {"Environment": env, "RunType": "once"})

# %%
# %run ./04-bronze

# %%
# %run ./05-silver

# %%
# %run ./06-gold

# %%
BZ = Bronze(env)
SL = Silver(env)
GL = Gold(env)
BZ.validate(1)
SL.validate(1)
GL.validate(1)

# %%
PR.produce(2)
PR.validate(2)
dbutils.notebook.run("./07-run", 600, {"Environment": env, "RunType": "once"})

# %%
BZ.validate(2)
SL.validate(2)
GL.validate(2)
SH.cleanup()
