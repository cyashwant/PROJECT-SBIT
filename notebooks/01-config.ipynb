# %%
class Config:
    def __init__(self):
        self.base_dir_data = spark.sql('describe external location `data_zone`').collect()[0][1]
        self.base_dir_checkpoint = spark.sql('describe external location `checkpoint`').collect()[0][1]
        self.db_name = 'sbit_db'
        self.maxFilesPerTrigger = 1000
